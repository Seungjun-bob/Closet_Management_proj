# %%
import urllib.request
import requests
from bs4 import BeautifulSoup
import time

# %%
# 반소매 : 001001
# 긴소매 : 001010
# 셔츠 : 001002
# 카라 : 001003
# 스웨트셔츠: 001005
# 후드 : 001004
# 니트 : 001006

categories = {"short": "001001", "long":"001010", "shirts":"001002", "colar":"001003",
              "sweatshirt":"001005","hoodie":"001004","knit":"001005"}
for cat in category.items():
    print(cat[0],cat[1])
# Out:
# short 001001
# long 001010
# shirts 001002
# colar 001003
# sweatshirt 001005
# hoodie 001004
# knit 001005

# %% [markdown]
# # 상의_통합_칼라별

# %%
start = time.time()
colors = [1,2,7]

for cat in categories.items():
    for color in colors:
        n = 1
        for page in range(1,3):
            url = "https://www.musinsa.com/category/"+cat[1]+"?d_cat_cd=001001&brand=&rate=&page_kind=search&list_kind=small&sort=pop&sub_sort=&page="+str(page)+"&display_cnt=90&sale_goods=&group_sale=&kids=N&ex_soldout=&color="+str(color)+"&price1=&price2=&exclusive_yn=&shoeSizeOption=&tags=&campaign_id=&timesale_yn=&q=&includeKeywords=&measure="
            req = requests.get(url)

            html = req.content
            html = html.decode('utf-8')

            bs = BeautifulSoup(html, 'html.parser')
            img = bs.select('#searchList > li > div.li_inner > div.list_img > a > img')

            if color == 1:
                for content in img:
                    imgUrl = content["data-original"]
                    with urllib.request.urlopen(imgUrl) as f:
                        with open('./images/top/top_'+cat[0]+'_white/top_'+cat[0]+'_white' + str(n)+'.jpg','wb') as h:
                            img = f.read()
                            h.write(img)
                    n += 1
            elif color == 2:
                for content in img:
                    imgUrl = content["data-original"]
                    with urllib.request.urlopen(imgUrl) as f:
                        with open('./images/top/top_'+cat[0]+'_black/top_'+cat[0]+'_black' + str(n)+'.jpg','wb') as h:
                            img = f.read()
                            h.write(img)
                    n += 1
            elif color == 7:
                for content in img:
                    imgUrl = content["data-original"]
                    with urllib.request.urlopen(imgUrl) as f:
                        with open('./images/top/top_'+cat[0]+'_blue/top_'+cat[0]+'_blue' + str(n)+'.jpg','wb') as h:
                            img = f.read()
                            h.write(img)
                    n += 1
            print(cat[0],"page",page,":", time.time() - start)
# Out:
# short page 1 : 11.594434976577759
# short page 2 : 24.60521364212036
# short page 1 : 36.16885733604431
# short page 2 : 47.280328035354614
# short page 1 : 58.30189633369446
# short page 2 : 68.70061922073364
# long page 1 : 80.48541069030762
# long page 2 : 92.56353402137756
# long page 1 : 104.53942131996155
# long page 2 : 117.25550985336304
# long page 1 : 129.93035221099854
# long page 2 : 142.68179535865784
# shirts page 1 : 154.470046043396
# shirts page 2 : 166.75596237182617
# shirts page 1 : 179.1431589126587
# shirts page 2 : 191.9733021259308
# shirts page 1 : 205.08542156219482
# shirts page 2 : 218.8431794643402
# colar page 1 : 231.819566488266
# colar page 2 : 244.5275740623474
# colar page 1 : 256.9401912689209
# colar page 2 : 269.36595821380615
# colar page 1 : 282.00122928619385
# colar page 2 : 294.29085421562195
# sweatshirt page 1 : 308.9346992969513
# sweatshirt page 2 : 323.07257628440857
# sweatshirt page 1 : 337.0337142944336
# sweatshirt page 2 : 350.6690261363983
# sweatshirt page 1 : 364.2892220020294
# sweatshirt page 2 : 377.74785923957825
# hoodie page 1 : 390.9359221458435
# hoodie page 2 : 404.62957549095154
# hoodie page 1 : 418.0804650783539
# hoodie page 2 : 431.881400346756
# hoodie page 1 : 444.82506465911865
# hoodie page 2 : 458.3114182949066
# knit page 1 : 471.2952575683594
# knit page 2 : 483.80894231796265
# knit page 1 : 496.6637499332428
# knit page 2 : 510.59047651290894
# knit page 1 : 523.8616316318512
# knit page 2 : 536.8340330123901

# %% [markdown]
# # 반소매

# %%
start = time.time()

n = 1
for page in range(100):
    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=001&subCategory=001001&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page=" + str(page) + "&viewType=small&priceMin=&priceMax="

    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    
    for content in img:
        imgUrl = content["data-original"]
        with urllib.request.urlopen(imgUrl) as f:
            with open('./images/top_short_all/top_short_all' + str(n)+'.jpg','wb') as h:
                img = f.read()
                h.write(img)
        n += 1
    print("page",page,":", time.time() - start)

# %% [markdown]
# # 긴소매

# %%
start = time.time()
n = 1
for page in range(1,101):

    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=001&subCategory=001010&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page=" + str(page) + "&viewType=small&priceMin=&priceMax="

    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    for content in img:
        try:
            imgUrl = content["data-original"]
            with urllib.request.urlopen(imgUrl) as f:
                with open('./images/top_long_all/top_long_all' + str(n)+'.jpg','wb') as h:
                    img = f.read()
                    h.write(img)
            n += 1
        except:
            pass
    print("page",page,":", time.time() - start)

# %% [markdown]
# # 셔츠

# %%
start = time.time()
n = 1
for page in range(1,101):

    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=001&subCategory=001002&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page="+str(page)+"&viewType=small&priceMin=&priceMax="

    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    for content in img:
        try:
            imgUrl = content["data-original"]
            with urllib.request.urlopen(imgUrl) as f:
                with open('./images/top_shirts/top_shirts' + str(n)+'.jpg','wb') as h:
                    img = f.read()
                    h.write(img)
            n += 1
        except:
            pass
    print("page",page,":", time.time() - start)

# %%
start = time.time()
n = 1
for page in range(1,55):

    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=001&subCategory=001003&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page="+str(page)+"&viewType=small&priceMin=&priceMax="

    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    for content in img:
        try:
            imgUrl = content["data-original"]
            with urllib.request.urlopen(imgUrl) as f:
                with open('./images/top_collar/top_collar' + str(n)+'.jpg','wb') as h:
                    img = f.read()
                    h.write(img)
            n += 1
        except:
            pass
    print("page",page,":", time.time() - start)

# %%
start = time.time()
n = 1
for page in range(1,101):

    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=001&subCategory=001005&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page="+str(page)+"&viewType=small&priceMin=&priceMax="

    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    for content in img:
        try:
            imgUrl = content["data-original"]
            with urllib.request.urlopen(imgUrl) as f:
                with open('./images/top_Sweatshirt/top_Sweatshirt' + str(n)+'.jpg','wb') as h:
                    img = f.read()
                    h.write(img)
            n += 1
        except:
            pass
    print("page",page,":", time.time() - start)

# %%
start = time.time()
n = 1
for page in range(1,101):

    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=001&subCategory=001004&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page="+str(page)+"&viewType=small&priceMin=&priceMax="

    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    for content in img:
        try:
            imgUrl = content["data-original"]
            with urllib.request.urlopen(imgUrl) as f:
                with open('./images/top_Hoodie/top_Hoodie' + str(n)+'.jpg','wb') as h:
                    img = f.read()
                    h.write(img)
            n += 1
        except:
            pass
    print("page",page,":", time.time() - start)

# %%
start = time.time()
n = 1
for page in range(1,101):

    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=001&subCategory=001006&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page="+str(page)+"&viewType=small&priceMin=&priceMax="

    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    for content in img:
        try:
            imgUrl = content["data-original"]
            with urllib.request.urlopen(imgUrl) as f:
                with open('./images/top_Knit/top_Knit' + str(n)+'.jpg','wb') as h:
                    img = f.read()
                    h.write(img)
            n += 1
        except:
            pass
    print("page",page,":", time.time() - start)
