# %%
import urllib.request
import requests
from bs4 import BeautifulSoup
import time

# %%
# 반소매 : 001001
# 긴소매 : 001010
# 셔츠 : 001002
# 카라 : 001003
# 스웨트셔츠: 001005
# 후드 : 001004
# 니트 : 001006
rankin_cat = []
mainCategory = {"top":"001", "bottom":"003"}
top_categories = {"short": "001001", "long":"001010", "shirts":"001002", "colar":"001003",
                  "sweatshirt":"001005","hoodie":"001004","knit":"001005"}
bottom_categories = {"cotton":"003007","jean":"003002","jogger":"003004","shorts":"003009","slacks":"003008"}
others = {"onepiece":"020", "skirt":"022"}

# colors = {"black":"2","white":"1","blue":"7"}
for cat in top_categories.items():
    print(cat[0],cat[1])
# Out:
# short 001001
# long 001010
# shirts 001002
# colar 001003
# sweatshirt 001005
# hoodie 001004
# knit 001005

# %% [markdown]
# # 상의_통합_칼라별

# %%
start = time.time()
n = 1
for cat in top_categories.items():        
    i = 1
    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=001&subCategory=" + cat[1] + "&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page=1&viewType=small&priceMin=&priceMax="
    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    for content in img:
        imgUrl = content["data-original"]
        with urllib.request.urlopen(imgUrl) as f:
            with open('./images/ranking/rank'+str(n)+'.jpg','wb') as h:
                img = f.read()
                h.write(img)
            n += 1
            i += 1
            if i > 20:
                break

        print('001', cat[1], time.time() - start)
# Out:
# 001 001001 0.6459944248199463
# 001 001001 0.786095142364502
# 001 001001 0.9344112873077393
# 001 001001 1.0494379997253418
# 001 001001 1.1757187843322754
# 001 001001 1.2947258949279785
# 001 001001 1.407726526260376
# 001 001001 1.515735387802124
# 001 001001 1.6092548370361328
# 001 001001 1.7094941139221191
# 001 001001 1.8086085319519043
# 001 001001 1.9141247272491455
# 001 001001 2.0321359634399414
# 001 001001 2.170661687850952
# 001 001001 2.322676181793213
# 001 001001 2.430802345275879
# 001 001001 2.5337564945220947
# 001 001001 2.668163299560547
# 001 001001 2.7811737060546875
# 001 001010 3.7637925148010254
# 001 001010 3.8501832485198975
# 001 001010 3.9306468963623047
# 001 001010 4.029051065444946
# 001 001010 4.147575378417969
# 001 001010 4.268052816390991
# 001 001010 4.389498710632324
# 001 001010 4.4889631271362305
# 001 001010 4.610653877258301
# 001 001010 4.724733591079712
# 001 001010 4.826136350631714
# 001 001010 4.9340057373046875
# ...

# %%
start = time.time()
for cat in bottom_categories.items():        
    i = 1
    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=003&subCategory=" + cat[1] + "&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page=1&viewType=small&priceMin=&priceMax="
    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    for content in img:
        imgUrl = content["data-original"]
        with urllib.request.urlopen(imgUrl) as f:
            with open('./images/ranking/rank'+str(n)+'.jpg','wb') as h:
                img = f.read()
                h.write(img)
            n += 1
            i += 1
            if i > 20:
                break

        print('003', cat[1], time.time() - start)
# Out:
# 003 003007 1.0495970249176025
# 003 003007 1.1777782440185547
# 003 003007 1.3084990978240967
# 003 003007 1.5701515674591064
# 003 003007 1.7769370079040527
# 003 003007 1.9825143814086914
# 003 003007 2.152050018310547
# 003 003007 2.3528640270233154
# 003 003007 2.544874668121338
# 003 003007 2.7323248386383057
# 003 003007 2.9463729858398438
# 003 003007 3.244917392730713
# 003 003007 3.455638885498047
# 003 003007 3.668058156967163
# 003 003007 3.8420770168304443
# 003 003007 3.998724937438965
# 003 003007 4.178122520446777
# 003 003007 4.47310996055603
# 003 003007 4.626382827758789
# 003 003002 5.68506121635437
# 003 003002 5.823967695236206
# 003 003002 5.9847166538238525
# 003 003002 6.131016731262207
# 003 003002 6.31235671043396
# 003 003002 6.512300252914429
# 003 003002 6.665316820144653
# 003 003002 6.804327964782715
# 003 003002 6.995485305786133
# 003 003002 7.21764874458313
# 003 003002 7.442195653915405
# 003 003002 7.606543064117432
# 003 003002 7.779067277908325
# ...

# %%
start = time.time()
for cat in others.items():        
    i = 1
    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory="+cat[1]+"&subCategory=&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page=1&viewType=small&priceMin=&priceMax="
    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    for content in img:
        imgUrl = content["data-original"]
        with urllib.request.urlopen(imgUrl) as f:
            with open('./images/ranking/rank'+str(n)+'.jpg','wb') as h:
                img = f.read()
                h.write(img)
            n += 1
            i += 1
            if i > 20:
                break

        print(cat[1], time.time() - start)
# Out:
# 020 0.826146125793457
# 020 0.9471421241760254
# 020 1.0981576442718506
# 020 1.2273085117340088
# 020 1.4136691093444824
# 020 1.5900859832763672
# 020 1.7416753768920898
# 020 1.8906378746032715
# 020 2.043933868408203
# 020 2.1874616146087646
# 020 2.345036506652832
# 020 2.554003953933716
# 020 2.7145421504974365
# 020 2.9862608909606934
# 020 3.1190690994262695
# 020 3.263359785079956
# 020 3.4675848484039307
# 020 3.6455116271972656
# 020 3.8712048530578613
# 022 5.181473731994629
# 022 5.336206436157227
# 022 5.507333755493164
# 022 5.66714334487915
# 022 5.814224720001221
# 022 5.972142696380615
# 022 6.151188373565674
# 022 6.340151786804199
# 022 6.500372648239136
# 022 6.647349834442139
# 022 6.855427503585815
# 022 7.042356014251709
# 022 7.2528886795043945
# 022 7.454676866531372
# 022 7.67223334312439
# 022 7.8319995403289795
# 022 7.971009016036987
# 022 8.09760594367981
# 022 8.25771427154541

# %% [markdown]
# # 하의_통합_칼라별

# %%
start = time.time()

for cat in bottom_categories.items():
    for color in colors.items():
        n = 1
        for page in range(1,3):
            url = "https://www.musinsa.com/category/"+cat[1]+"?d_cat_cd="+cat[1]+"&brand=&rate=&page_kind=search&list_kind=small&sort=pop&sub_sort=&page="+str(page)+"&display_cnt=90&sale_goods=&group_sale=&kids=N&ex_soldout=&color="+color[1]+"&price1=&price2=&exclusive_yn=&shoeSizeOption=&tags=&campaign_id=&timesale_yn=&q=&includeKeywords=&measure="
            req = requests.get(url)

            html = req.content
            html = html.decode('utf-8')

            bs = BeautifulSoup(html, 'html.parser')
            img = bs.select('#searchList > li > div.li_inner > div.list_img > a > img')

            for content in img:
                imgUrl = content["data-original"]
                with urllib.request.urlopen(imgUrl) as f:
                    with open('./images/bottom_color/bottom_'+cat[0]+'_'+color[0]+'/bottom_'+cat[0]+'_'+color[0] + str(n)+'.jpg','wb') as h:
                        img = f.read()
                        h.write(img)
                n += 1

            print(cat[0],color[0],"page",page,":", time.time() - start)
# Out:
# cotton black page 1 : 14.833759546279907
# cotton black page 2 : 29.20614528656006
# cotton white page 1 : 45.55396890640259
# cotton white page 2 : 61.88291382789612
# cotton blue page 1 : 77.08422827720642
# cotton blue page 2 : 91.88479495048523
# jean black page 1 : 106.99460792541504
# jean black page 2 : 122.46460485458374
# jean white page 1 : 137.5192940235138
# jean white page 2 : 153.08321332931519
# jean blue page 1 : 169.76113080978394
# jean blue page 2 : 185.96332049369812
# jogger black page 1 : 199.29874682426453
# jogger black page 2 : 214.95014643669128
# jogger white page 1 : 230.49076795578003
# jogger white page 2 : 245.74824738502502
# jogger blue page 1 : 264.46037578582764
# jogger blue page 2 : 283.6210026741028
# shorts black page 1 : 297.74495005607605
# shorts black page 2 : 311.60368061065674
# shorts white page 1 : 327.93457674980164
# shorts white page 2 : 344.9406044483185
# shorts blue page 1 : 361.124618768692
# ...

# %% [markdown]
# # 원피스 / 스커트

# %%
start = time.time()

for cat in others.items():
    for color in colors.items():
        n = 1
        for page in range(1,3):
            url = "https://www.musinsa.com/category/"+cat[1]+"?d_cat_cd="+cat[1]+"&brand=&rate=&page_kind=search&list_kind=small&sort=pop&sub_sort=&page="+str(page)+"&display_cnt=90&sale_goods=&group_sale=&kids=N&ex_soldout=&color="+color[1]+"&price1=&price2=&exclusive_yn=&shoeSizeOption=&tags=&campaign_id=&timesale_yn=&q=&includeKeywords=&measure="
            req = requests.get(url)

            html = req.content
            html = html.decode('utf-8')

            bs = BeautifulSoup(html, 'html.parser')
            img = bs.select('#searchList > li > div.li_inner > div.list_img > a > img')

            for content in img:
                imgUrl = content["data-original"]
                with urllib.request.urlopen(imgUrl) as f:
                    with open('./images/others_color/'+cat[0]+'_'+color[0]+'/'+cat[0]+'_'+color[0] + str(n)+'.jpg','wb') as h:
                        img = f.read()
                        h.write(img)
                n += 1

            print(cat[0],color[0],"page",page,":", time.time() - start)
# Out:
# onepiece black page 1 : 13.314269304275513
# onepiece black page 2 : 26.859031200408936
# onepiece white page 1 : 42.71025013923645
# onepiece white page 2 : 59.88700819015503
# onepiece blue page 1 : 76.08693623542786
# onepiece blue page 2 : 95.51476621627808
# skirt black page 1 : 113.36364006996155
# skirt black page 2 : 130.90069937705994
# skirt white page 1 : 145.54562711715698
# skirt white page 2 : 182.19632411003113
# skirt blue page 1 : 197.74726605415344
# skirt blue page 2 : 217.10166430473328

# %% [markdown]
# # 반소매

# %%
start = time.time()

n = 1
for page in range(100):
    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=001&subCategory=001001&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page=" + str(page) + "&viewType=small&priceMin=&priceMax="

    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    
    for content in img:
        imgUrl = content["data-original"]
        with urllib.request.urlopen(imgUrl) as f:
            with open('./images/top_short_all/top_short_all' + str(n)+'.jpg','wb') as h:
                img = f.read()
                h.write(img)
        n += 1
    print("page",page,":", time.time() - start)

# %% [markdown]
# # 긴소매

# %%
start = time.time()
n = 1
for page in range(1,101):

    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=001&subCategory=001010&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page=" + str(page) + "&viewType=small&priceMin=&priceMax="

    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    for content in img:
        try:
            imgUrl = content["data-original"]
            with urllib.request.urlopen(imgUrl) as f:
                with open('./images/top_long_all/top_long_all' + str(n)+'.jpg','wb') as h:
                    img = f.read()
                    h.write(img)
            n += 1
        except:
            pass
    print("page",page,":", time.time() - start)

# %% [markdown]
# # 셔츠

# %%
start = time.time()
n = 1
for page in range(1,101):

    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=001&subCategory=001002&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page="+str(page)+"&viewType=small&priceMin=&priceMax="

    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    for content in img:
        try:
            imgUrl = content["data-original"]
            with urllib.request.urlopen(imgUrl) as f:
                with open('./images/top_shirts/top_shirts' + str(n)+'.jpg','wb') as h:
                    img = f.read()
                    h.write(img)
            n += 1
        except:
            pass
    print("page",page,":", time.time() - start)

# %%
start = time.time()
n = 1
for page in range(1,55):

    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=001&subCategory=001003&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page="+str(page)+"&viewType=small&priceMin=&priceMax="

    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    for content in img:
        try:
            imgUrl = content["data-original"]
            with urllib.request.urlopen(imgUrl) as f:
                with open('./images/top_collar/top_collar' + str(n)+'.jpg','wb') as h:
                    img = f.read()
                    h.write(img)
            n += 1
        except:
            pass
    print("page",page,":", time.time() - start)

# %%
start = time.time()
n = 1
for page in range(1,101):

    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=001&subCategory=001005&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page="+str(page)+"&viewType=small&priceMin=&priceMax="

    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    for content in img:
        try:
            imgUrl = content["data-original"]
            with urllib.request.urlopen(imgUrl) as f:
                with open('./images/top_Sweatshirt/top_Sweatshirt' + str(n)+'.jpg','wb') as h:
                    img = f.read()
                    h.write(img)
            n += 1
        except:
            pass
    print("page",page,":", time.time() - start)

# %%
start = time.time()
n = 1
for page in range(1,101):

    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=001&subCategory=001004&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page="+str(page)+"&viewType=small&priceMin=&priceMax="

    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    for content in img:
        try:
            imgUrl = content["data-original"]
            with urllib.request.urlopen(imgUrl) as f:
                with open('./images/top_Hoodie/top_Hoodie' + str(n)+'.jpg','wb') as h:
                    img = f.read()
                    h.write(img)
            n += 1
        except:
            pass
    print("page",page,":", time.time() - start)

# %%
start = time.time()
n = 1
for page in range(1,101):

    url = "https://www.musinsa.com/ranking/best?period=now&age=ALL&mainCategory=001&subCategory=001006&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page="+str(page)+"&viewType=small&priceMin=&priceMax="

    req = requests.get(url)

    html = req.content
    html = html.decode('utf-8')

    bs = BeautifulSoup(html, 'html.parser')
    img = bs.select('#goodsRankList > li > div.li_inner > div.list_img > a > img')

    for content in img:
        try:
            imgUrl = content["data-original"]
            with urllib.request.urlopen(imgUrl) as f:
                with open('./images/top_Knit/top_Knit' + str(n)+'.jpg','wb') as h:
                    img = f.read()
                    h.write(img)
            n += 1
        except:
            pass
    print("page",page,":", time.time() - start)
